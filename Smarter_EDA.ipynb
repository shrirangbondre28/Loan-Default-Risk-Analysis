# %%
import pandas as pd
from ydata_profiling import ProfileReport
import webbrowser

# %%
df = pd.read_csv("C:\\Users\\shrir\\Downloads\\Loan_default.csv")

# %%
profile = ProfileReport(df, title="Loan Default EDA Report", explorative=True)
profile.to_file("loan_default_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
webbrowser.open("loan_default_report.html")
